# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('./data/iris3.csv')

# %%
# 150 X 5

# %%
iris.info()

# %%
iris.species

# %%
iris.values

# %%
iris.values[:, 4]

# %%
# help(pd.get_dummies)

# %%
pd.get_dummies(iris['species'])

# %%
iris_species2 = iris['species']

# %%
iris_species2

# %%
# 원-핫 인코딩(One-Hot Encoding)을 수행하려면, 먼저 각 클래스가 고유한 정수 값(예: 0, 1, 2)으로 표현되어 있어야 합니다.
# 원-핫 인코딩은 이 정수 값을 기반으로 클래스를 이진 벡터로 변환하는 과정

# %%
iris_species2.replace({'Iris-setosa': 0, 'Iris-versicolor': 1,
                      'Iris-virginica': 2}, inplace=True)

# %%
iris_species2

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehotEncoder = OneHotEncoder()

# %%
iris_species2.shape

# %%
type(iris)

# %%
np.array(iris['species']).reshape(150, -1)

# %%
iris_label2d = np.array(iris['species']).reshape(150, -1)

# %%
onehotEncoder.fit_transform(iris_label2d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X = iris.iloc[:, :4]
y = iris.iloc[:, 4]

# %%
y

# %%
y_encode = pd.get_dummies(y)

# %%
y_encode

# %%
model2 = Sequential()
model2.add(Dense(12, input_dim=4, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(3, activation='softmax'))
model2.compile(loss='categorical_crossentropy',
               optimizer='adam', metrics=['accuracy'])
model2.fit(X, y_encode, epochs=50, batch_size=5)
# Out:
# Epoch 1/50
# c:\ProgramData\anaconda3\envs\mldltest2\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3335 - loss: 2.1303
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3267 - loss: 1.4861
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.2851 - loss: 1.1749
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3142 - loss: 0.9940
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.5536 - loss: 0.8315
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5983 - loss: 0.8730
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7303 - loss: 0.7860
# Epoch 8/50
# ...

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 12)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 575 (2.25 KB)
#  Trainable params: 191 (764.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 384 (1.50 KB)

# %%
X.iloc[:1, :4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2

# %%
model2.predict(X.iloc[:1, :4])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# array([[9.9433362e-01, 5.5215838e-03, 1.4490001e-04]], dtype=float32)

# %%
np.round(model2.predict(X.iloc[:1, :4]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# array([[1., 0., 0.]], dtype=float32)

# %%
predictions = model2.predict(X)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
