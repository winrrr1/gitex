# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/pima-indians-diabetes3.csv')
df.head()
# Out:
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['diabetes'].value_counts() # 벨류 카운트 함수를 이용하면 각컬럼이 몇개씩 있는지 알려줌
# Out:
# diabetes
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr() # 상관관계
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# ...

# %%
# https://matplotlib.org/2.0.2/users/colormaps.html 사이트에서 컬러맵 색상 종류 볼수 있음 
colormap = plt.cm.gist_heat # 그래프 색상 구성을 정한다. 
plt.figure(figsize=(12,12)) # 그래프의 크기 피그사이즈 ()
sns.heatmap(df.corr(), linewidths=0.1, vmax=0.5, cmap = colormap, linecolor='white',annot=True)
# heatmap() 함수 두 항목씩 짝을 지은후 각각 어떤 패턴으로 변화하는지 관찰하는 함수 
# vmax 는 색상밝기, cmap = 미리 정해진 맷플롯립 색상의 설정값 불러옮. 
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(x=[df.plasma[df.diabetes==0], df.plasma[df.diabetes==1]], bins=30, histtype='barstacked', label=['normal','diabetes'])
plt.legend() # 각 실행되는 컬럼스들의 범례를 우측위에 표시해준다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('./data/pima-indians-diabetes3.csv')
df
# Out:
#      pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0           6     148        72         35        0  33.6     0.627   50
# 1           1      85        66         29        0  26.6     0.351   31
# 2           8     183        64          0        0  23.3     0.672   32
# 3           1      89        66         23       94  28.1     0.167   21
# 4           0     137        40         35      168  43.1     2.288   33
# ..        ...     ...       ...        ...      ...   ...       ...  ...
# 763        10     101        76         48      180  32.9     0.171   63
# 764         2     122        70         27        0  36.8     0.340   27
# 765         5     121        72         23      112  26.2     0.245   30
# 766         1     126        60          0        0  30.1     0.349   47
# 767         1      93        70         31        0  30.4     0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = df.iloc[:,0:8] # 세부정보를 x로 지정
y = df.iloc[:,8] # 당뇨병 여부를 y로 지정

# %%
X.shape
# Out:
# (768, 8)

# %%
y.shape
# Out:
# (768,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim =8, activation = 'relu', name='Dense_1'))
model.add(Dense(8, activation='relu', name='Dense_2'))
model.add(Dense(1, activation='sigmoid', name='Dense_3'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense_1 (Dense)             (None, 12)                108
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 221 (884.00 Byte)
# Trainable params: 221 (884.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, epochs=200, batch_size=5)
# Out:
# Epoch 1/200
# 154/154 [==============================] - 1s 1ms/step - loss: 5.9901 - accuracy: 0.6250
# Epoch 2/200
# 154/154 [==============================] - 0s 920us/step - loss: 1.7371 - accuracy: 0.5859
# Epoch 3/200
# 154/154 [==============================] - 0s 907us/step - loss: 1.0670 - accuracy: 0.5768
# Epoch 4/200
# 154/154 [==============================] - 0s 857us/step - loss: 0.8505 - accuracy: 0.5872
# Epoch 5/200
# 154/154 [==============================] - 0s 863us/step - loss: 0.7743 - accuracy: 0.5755
# Epoch 6/200
# 154/154 [==============================] - 0s 843us/step - loss: 0.7047 - accuracy: 0.6055
# Epoch 7/200
# 154/154 [==============================] - 0s 920us/step - loss: 0.6914 - accuracy: 0.6185
# Epoch 8/200
# 154/154 [==============================] - 0s 803us/step - loss: 0.6673 - accuracy: 0.6133
# Epoch 9/200
# 154/154 [==============================] - 0s 866us/step - loss: 0.6475 - accuracy: 0.6445
# Epoch 10/200
# ...

# %%
# 약 75.52% 정확도 / 할때마다 정확도가 높아짐  / epochs 를 많이 하면 정확도가 높아짐 이값은 100번 했을때 수치

# %%
768/5 # 153.6 이라서 154 번돌림
# Out:
# 153.6
