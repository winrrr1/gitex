# %% [markdown]
# ## x에 대한 편미분 (partial)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy as sp

# %%
# 심볼릭 변수 정의
x, y, a = sp.symbols('x y a')

# %%
# 함수 정의
f = x**2 + y*x + a

# %%
# f를 x에 대한 편미분
sp.diff(f, x)
# Out:
# 2*x + y

# %%
# f를 y에 대한 편미분
sp.diff(f,y)
# Out:
# x
